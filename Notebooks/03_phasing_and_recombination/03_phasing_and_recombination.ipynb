# %% [markdown]
# # Phasing and recombination tutorial
#
# In this tutorial you will extract information about the genotype phases and the recombination rate starting from VCF files.
#
# ## How to make this notebook work
#
# * In this notebook we will use both the `command line bash` commands and `R` to setup the file folders.
# * Having to shift between two languages, you need to choose a kernel every time we shift from one language to another. A kernel contains a programming language and the necessary packages to run the course material. To choose a kernel, go on the menu on the top of the page and select `Kernel --> Change Kernel`, and then select the preferred one. We will shift between two kernels, and along the code in this notebook you will see a picture telling you to change kernel. The two pictures are below:
#
# <img src="img/bash.png" alt="Bash" width="80"> Shift to the `Bash` kernel
#
# <img src="img/R.png" alt="R" width="80"> Shift to the `popgen course` kernel
# * You can run the code in each cell by clicking on the run cell sign in the toolbar, or simply by pressing <kbd>Shift</kbd>+<kbd>Enter</kbd>. When the code is done running, a small green check sign will appear on the left side.
# * You need to run the cells in sequential order to execute the analysis. Please do not run a cell until the one above is done running, and do not skip any cells
# * The code goes along with textual descriptions to help you understand what happens. Please try not to focus on understanding the code itself in too much detail - but rather try to focus on the explanations and on the output of the commands
# *   You can create new code cells by pressing `+` in the Menu bar above or by pressing <kbd>B</kbd> after you select a cell.
#
#
# ## Learning outcomes
#
# At the end of this tutorial you will be able to
#
# - **Create** phased data and **discuss** the results through the genome viewer
# - **Estimate and analyze** recombination maps
# - **Plot** recombination maps in `R` and **compare** different populations
#
# ## Setting up folders
#
# Here we setup a link to the `Data` folder and create the `Results` folder
#
# <img src="img/bash.png" alt="Bash" width="80"> Choose the `Bash` kernel

# %%
ln -s ../../Data
mkdir -p Results

# %% [markdown]
# # Inferring the genotype phase (AKA Phasing)
#
# During base calling, we identified the two bases at each position in each diploid individual. However, we do not know which base goes on which of the two chromosomes. That means that we do not know if the two haploid chromosomes look like the left or right example below:
#
#     -----A-----C------         -----T-----C------
#     -----T-----G------    or   -----A-----G------
#
#
# To do that we use the program [Beagle](http://faculty.washington.edu/browning/beagle/beagle.html), which applies a clustering algorithm to call the genotype phase.
#
# We put the jointly called bases for Africans, West Eurasians, and East Asians in these three files:
#
# - Africa (9 individuals): `Data/vcf/Allvariants_africa.vcf`
# - West Eurasia (10 individuals): `Data/vcf/Allvariants_westeurasia.vcf`
# - Eash Asia (8 individuals): `Data/vcf/Allvariants_eastasia.vcf`
#
# In this exercise we will just use the Africans and the West Eurasians.

# %% [markdown]
# ## Running Beagle
#
# For additional information see the [Beagle 4.1 manual](https://faculty.washington.edu/browning/beagle/beagle_4.1_03Oct15.pdf)
#
# To obtain phased data, Beagle needs a [genetic map](https://www.genome.gov/genetics-glossary/Genetic-Map). Genetic maps for widely used organisms (humans, mice, yeast, ...) are already available online. You can find the genetic map for chr2 (hg19 assembly) here: `Data/genetic_map/plink.chr2.GRCh37.map`.
#
# We run `Beagle` on the african vcf file. `Beagle` is written in `java` language in a file with extension `.jar`, so we call it using `java -jar`.

# %%
java -jar Data/software/beagle.08Jun17.d8b.jar \
        gt=Data/vcf/Allvariants_africa.vcf \
        map=Data/genetic_map/plink.chr2.GRCh37.map \
        out=Results/Allvariants_africa_phased
# Out:
# beagle.08Jun17.d8b.jar (version 4.1)
# Copyright (C) 2014-2015 Brian L. Browning
# Enter "java -jar beagle.08Jun17.d8b.jar" for a summary of command line arguments.
# Start time: 11:42 AM CEST on 31 Mar 2023
#
# Command line: java -Xmx22412m -jar beagle.jar
#   gt=Data/vcf/Allvariants_africa.vcf
#   map=Data/genetic_map/plink.chr2.GRCh37.map
#   out=Results/Allvariants_africa_phased
#
# reference samples:       0
# target samples:         10
#
# Window 1 [ 2:135000277-144999565 ]
# target markers:      49868
#
# Starting burn-in iterations
#
# Window=1 Iteration=1
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 3      max edges/level: 8
# mean edges/node:  1.594  mean count/edge: 7
#
# Window=1 Iteration=2
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 3      max edges/level: 9
# mean edges/node:  1.459  mean count/edge: 7
#
# Window=1 Iteration=3
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 3      max edges/level: 10
# mean edges/node:  1.336  mean count/edge: 7
#
# Window=1 Iteration=4
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 4      max edges/level: 10
# mean edges/node:  1.279  mean count/edge: 5
#
# Window=1 Iteration=5
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 4      max edges/level: 10
# mean edges/node:  1.247  mean count/edge: 5
#
# Window=1 Iteration=6
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 4      max edges/level: 10
# mean edges/node:  1.226  mean count/edge: 5
#
# Window=1 Iteration=7
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 4      max edges/level: 10
# mean edges/node:  1.207  mean count/edge: 5
#
# Window=1 Iteration=8
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 4      max edges/level: 10
# mean edges/node:  1.199  mean count/edge: 5
#
# Window=1 Iteration=9
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 4      max edges/level: 10
# mean edges/node:  1.190  mean count/edge: 5
#
# Window=1 Iteration=10
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 4      max edges/level: 10
# mean edges/node:  1.182  mean count/edge: 5
#
# Starting phasing iterations
#
# Window=1 Iteration=11
# Time for building model:         0 seconds
# Time for sampling (singles):     1 second
# DAG statistics
# mean edges/level: 5      max edges/level: 11
# mean edges/node:  1.126  mean count/edge: 4
#
# Window=1 Iteration=12
# Time for building model:         1 second
# Time for sampling (singles):     1 second
# DAG statistics
# mean edges/level: 6      max edges/level: 11
# mean edges/node:  1.115  mean count/edge: 3
#
# Window=1 Iteration=13
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 4      max edges/level: 11
# mean edges/node:  1.136  mean count/edge: 5
#
# Window=1 Iteration=14
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 5      max edges/level: 12
# mean edges/node:  1.114  mean count/edge: 4
#
# Window=1 Iteration=15
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 5      max edges/level: 11
# mean edges/node:  1.123  mean count/edge: 4
#
# Number of markers:               49868
# Total time for building model: 7 seconds
# Total time for sampling:       5 seconds
# Total run time:                14 seconds
#
# End time: 11:42 AM CEST on 31 Mar 2023
# beagle.08Jun17.d8b.jar (version 4.1) finished

# %% [markdown]
# We run the same command for the west eurasian vsc file:

# %%
java -jar Data/software/beagle.08Jun17.d8b.jar \
        gt=Data/vcf/Allvariants_westeurasia.vcf \
        map=Data/genetic_map/plink.chr2.GRCh37.map \
        out=Results/Allvariants_westeurasia_phased
# Out:
# beagle.08Jun17.d8b.jar (version 4.1)
# Copyright (C) 2014-2015 Brian L. Browning
# Enter "java -jar beagle.08Jun17.d8b.jar" for a summary of command line arguments.
# Start time: 11:42 AM CEST on 31 Mar 2023
#
# Command line: java -Xmx22412m -jar beagle.jar
#   gt=Data/vcf/Allvariants_westeurasia.vcf
#   map=Data/genetic_map/plink.chr2.GRCh37.map
#   out=Results/Allvariants_westeurasia_phased
#
# reference samples:       0
# target samples:         10
#
# Window 1 [ 2:135000277-144999565 ]
# target markers:      49868
#
# Starting burn-in iterations
#
# Window=1 Iteration=1
# Time for building model:         1 second
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 3      max edges/level: 9
# mean edges/node:  1.225  mean count/edge: 7
#
# Window=1 Iteration=2
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 4      max edges/level: 9
# mean edges/node:  1.182  mean count/edge: 5
#
# Window=1 Iteration=3
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 4      max edges/level: 10
# mean edges/node:  1.140  mean count/edge: 5
#
# Window=1 Iteration=4
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 4      max edges/level: 12
# mean edges/node:  1.115  mean count/edge: 5
#
# Window=1 Iteration=5
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 4      max edges/level: 11
# mean edges/node:  1.100  mean count/edge: 5
#
# Window=1 Iteration=6
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 4      max edges/level: 11
# mean edges/node:  1.092  mean count/edge: 5
#
# Window=1 Iteration=7
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 4      max edges/level: 11
# mean edges/node:  1.083  mean count/edge: 5
#
# Window=1 Iteration=8
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 4      max edges/level: 11
# mean edges/node:  1.078  mean count/edge: 5
#
# Window=1 Iteration=9
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 5      max edges/level: 10
# mean edges/node:  1.075  mean count/edge: 4
#
# Window=1 Iteration=10
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 5      max edges/level: 11
# mean edges/node:  1.072  mean count/edge: 4
#
# Starting phasing iterations
#
# Window=1 Iteration=11
# Time for building model:         0 seconds
# Time for sampling (singles):     1 second
# DAG statistics
# mean edges/level: 5      max edges/level: 11
# mean edges/node:  1.055  mean count/edge: 4
#
# Window=1 Iteration=12
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 6      max edges/level: 11
# mean edges/node:  1.052  mean count/edge: 3
#
# Window=1 Iteration=13
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 6      max edges/level: 12
# mean edges/node:  1.049  mean count/edge: 3
#
# Window=1 Iteration=14
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 6      max edges/level: 13
# mean edges/node:  1.047  mean count/edge: 3
#
# Window=1 Iteration=15
# Time for building model:         0 seconds
# Time for sampling (singles):     0 seconds
# DAG statistics
# mean edges/level: 6      max edges/level: 12
# mean edges/node:  1.046  mean count/edge: 3
#
# Number of markers:               49868
# Total time for building model: 6 seconds
# Total time for sampling:       4 seconds
# Total run time:                12 seconds
#
# End time: 11:42 AM CEST on 31 Mar 2023
# beagle.08Jun17.d8b.jar (version 4.1) finished

# %% [markdown]
# Vcf files can both be compressed (gz) or uncompressed. IGV needs it in an uncompressed format, so decompress using

# %%
gunzip -c Results/Allvariants_africa_phased.vcf.gz > Results/Allvariants_africa_phased_t.vcf

# %%
gunzip -c Results/Allvariants_westeurasia_phased.vcf.gz > Results/Allvariants_westeurasia_phased_t.vcf

# %% [markdown]
# This command outputs the decompressed to stdout, which then is written into your file name of choice using `>`.

# %% [markdown]
# ## Browsing the phased results
#
# Download the phased VCF files to your computer and open them in IGV (integrative genomics viewer):
#
# 1. Choose Human hg19 as the reference genome.
# 2. Click `File > Load from File...` and select you phased VCF file.
#
# Explore phases of haplotypes at two positions in the alignment:
#
# Select chr2, zoom all the way in and select find the base at position 136608646. First, take a look at the WestEurasian samples. Consider these questions while zooming further out:
#
# 1. What does the haplotypes look like?
# 2. Do you see any long streches of homozygosity?
# 3. Which haplotypes agree?
# 4. How wide is the region where they agree?
#
# To help derive your answers, make use of the metadata file: `Data/metadata/Sample_meta_subset.tsv`
#
# Now, compare it with the African samples.
#
# Try to search the position chr2:136608646 in the [UCSC genome browser](https://genome-euro.ucsc.edu/cgi-bin/hgGateway?redirect=manual&source=genome.ucsc.edu). Remember we are using the Hg19 assembly version of the reference human genome. Can you find anything that explains your observations? (HINT: https://omim.org/entry/601806#0004)
#
# # Estimating a recombination map
#
# We use `LDhat`, a package for the analysis of recombination rates from population genetic data, to estimate a recombination map from the vcf files. The proportion of crossovers occurring between two genes can be used to indicate the distance between them, and thus enable the construction of a genetic map that illustrates how all genes in the genome are related in space.
#
# ## Format input data for LDhat
#
# LDhat needs its input data in a particular format ([LDhat  manual](https://github.com/auton1/LDhat/blob/master/manual.pdf)). We will use `vcftools` to produce these input files from the phased VCF file.
#
# For Africa:

# %%
vcftools --gzvcf Results/Allvariants_africa_phased.vcf.gz --chr 2 --ldhat --out Results/recmap_data_africa
# Out:
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf Results/Allvariants_africa_phased.vcf.gz
# 	--chr 2
# 	--out Results/recmap_data_africa
# 	--phased
# 	--ldhat
#
# Using zlib version: 1.2.11
# After filtering, kept 10 out of 10 Individuals
# Outputting in phased LDhat format
# After filtering, kept 49868 out of a possible 49868 Sites
# Run Time = 0.00 seconds

# %% [markdown]
# West Eurasia

# %%
vcftools --gzvcf Results/Allvariants_westeurasia_phased.vcf.gz --chr 2 --ldhat --out Results/recmap_data_westeurasia
# Out:
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf Results/Allvariants_westeurasia_phased.vcf.gz
# 	--chr 2
# 	--out Results/recmap_data_westeurasia
# 	--phased
# 	--ldhat
#
# Using zlib version: 1.2.11
# After filtering, kept 10 out of 10 Individuals
# Outputting in phased LDhat format
# After filtering, kept 49868 out of a possible 49868 Sites
# Run Time = 1.00 seconds

# %% [markdown]
# Have a look at the two files produced

# %%
head Results/recmap_data_westeurasia.ldhat.locs
# Out:
# 49868	144999.5650	L
# 135000.2770
# 135000.5000
# 135000.6740
# 135001.3970
# 135001.5380
# 135001.5950
# 135001.8450
# 135001.8870
# 135002.6710

# %%
head Results/recmap_data_westeurasia.ldhat.sites
# Out:
# 20	49868	1
# >ERR1025614-0
# ...
# >ERR1025614-1
# ...
# >ERR1025615-0
# ...
# >ERR1025615-1
# ...
# >ERR1025619-0

# %% [markdown]
# How do you think the information is encoded in these files?

# %% [markdown]
# ## Running LDhat
#
# To speed up computations you can make a lookup table first. That takes a while, so we did if for you. But it is done using the `complete` program that comes with LDhat as below (command is ineffective because commented with the `#` symbol). The parameters are
# - `-n 20`:the number of haplotypes (2 * 10).
# - `-rhomax 100`: maximum rho ($4N_e r$) alowed: 100 (recommended).
# - `-n_pts 101`: number of points in grid: 101 (recommended).
# - `-theta 0.0001`: human theta ($4N_e \mu$).

# %%
#Data/software/builds/LDhat/complete -n 20 -rhomax 100 -n_pts 101 -theta 0.0001

# %% [markdown]
# The output is a file that will serve as a look up table for the algorithm. It includes coalescent likelihoods for each pairs of SNPs using a grid of recombination rates. You can find it in `new_lk.txt` together with this notebook.

# %% [markdown]
# The next step is to calculate the recombination map. This command will take some time to run (~ 6 min). The options we are using are
# - `-lk`: likelihood lookup table.
# - `-its`: number of iterations of the MCMC.
# - `-samp`: number of iterations between sampling events, i.e how often to sample from the MCMC.
# - `-burn`: how many of the initial iterations to discard. Here we set it to zero to leave keep all samples. Then we look later how much burnin to discard.
#
# Africa:

# %%
Data/software/builds/LDhat/rhomap -seq Results/recmap_data_africa.ldhat.sites \
                                        -loc Results/recmap_data_africa.ldhat.locs \
                                        -prefix Results/recmap_data_africa. \
                                        -lk new_lk.txt -its 100000 -samp 500 -burn 0
# Out:
# Starting rate estimation
# Seed = -1680256120
# Analysing 20 haploid sequences of length 49868 seg sites
# Reading sequences in fasta format
# Reading data for pair types
#
# Checking likelihood file is exhaustive:...OK
# Calculating distribution of pair types
# Completed classification of pair types
# Old = 275: New = 0: Missing = 0
# Max number of haplotypes for n=20 is 275
# Reading likelihoods for pair types
#
# Initial likelihood = -461495.977
#
# Run      500: LK -46060716.418: ChangePoints 49714: Hotspots  178: MapLen 5962.110
# Run     1000: LK -46017483.355: ChangePoints 49570: Hotspots  307: MapLen 8966.393
# Run     1500: LK -45979302.142: ChangePoints 49427: Hotspots  367: MapLen 10589.567
# Run     2000: LK -45948694.152: ChangePoints 49285: Hotspots  417: MapLen 12756.490
# Run     2500: LK -45925522.290: ChangePoints 49156: Hotspots  454: MapLen 13420.341
# Run     3000: LK -45901065.651: ChangePoints 48995: Hotspots  504: MapLen 15488.581
# Run     3500: LK -45883658.375: ChangePoints 48847: Hotspots  514: MapLen 16050.366
# Run     4000: LK -45868862.094: ChangePoints 48727: Hotspots  555: MapLen 17613.075
# Run     4500: LK -45854961.970: ChangePoints 48594: Hotspots  575: MapLen 18200.666
# Run     5000: LK -45843146.613: ChangePoints 48465: Hotspots  606: MapLen 19025.586
# Run     5500: LK -45830343.601: ChangePoints 48348: Hotspots  629: MapLen 19231.199
# Run     6000: LK -45821379.267: ChangePoints 48224: Hotspots  642: MapLen 18784.186
# Run     6500: LK -45806934.906: ChangePoints 48101: Hotspots  655: MapLen 19377.637
# Run     7000: LK -45798653.739: ChangePoints 47975: Hotspots  670: MapLen 19980.813
# Run     7500: LK -45793211.651: ChangePoints 47856: Hotspots  683: MapLen 20257.078
# Run     8000: LK -45781573.340: ChangePoints 47717: Hotspots  691: MapLen 20835.628
# Run     8500: LK -45775908.160: ChangePoints 47582: Hotspots  691: MapLen 21347.900
# Run     9000: LK -45765737.776: ChangePoints 47446: Hotspots  726: MapLen 22504.445
# Run     9500: LK -45759170.952: ChangePoints 47328: Hotspots  748: MapLen 23123.251
# Run    10000: LK -45755008.140: ChangePoints 47188: Hotspots  741: MapLen 22350.974
# Run    10500: LK -45748205.949: ChangePoints 47055: Hotspots  741: MapLen 22146.016
# Run    11000: LK -45742651.400: ChangePoints 46916: Hotspots  754: MapLen 22352.834
# Run    11500: LK -45736175.236: ChangePoints 46789: Hotspots  758: MapLen 22573.721
# Run    12000: LK -45730209.226: ChangePoints 46669: Hotspots  770: MapLen 22910.063
# Run    12500: LK -45726262.646: ChangePoints 46558: Hotspots  766: MapLen 22394.795
# Run    13000: LK -45721733.623: ChangePoints 46427: Hotspots  771: MapLen 21977.027
# Run    13500: LK -45719684.961: ChangePoints 46307: Hotspots  773: MapLen 21730.230
# Run    14000: LK -45716260.905: ChangePoints 46189: Hotspots  790: MapLen 22384.503
# Run    14500: LK -45712207.546: ChangePoints 46054: Hotspots  783: MapLen 22545.494
# Run    15000: LK -45710005.301: ChangePoints 45939: Hotspots  780: MapLen 22036.367
# Run    15500: LK -45705951.417: ChangePoints 45824: Hotspots  792: MapLen 22377.446
# Run    16000: LK -45704407.416: ChangePoints 45696: Hotspots  809: MapLen 22394.252
# Run    16500: LK -45701381.700: ChangePoints 45603: Hotspots  811: MapLen 22283.948
# Run    17000: LK -45697081.032: ChangePoints 45486: Hotspots  821: MapLen 23319.606
# Run    17500: LK -45693016.804: ChangePoints 45374: Hotspots  828: MapLen 22888.830
# Run    18000: LK -45688513.883: ChangePoints 45241: Hotspots  832: MapLen 22957.052
# Run    18500: LK -45685768.466: ChangePoints 45128: Hotspots  834: MapLen 22871.545
# Run    19000: LK -45682475.130: ChangePoints 44994: Hotspots  833: MapLen 23670.411
# Run    19500: LK -45680674.897: ChangePoints 44872: Hotspots  853: MapLen 24462.563
# Run    20000: LK -45677938.525: ChangePoints 44739: Hotspots  852: MapLen 24950.280
# Run    20500: LK -45677951.206: ChangePoints 44621: Hotspots  848: MapLen 25218.468
# Run    21000: LK -45677905.987: ChangePoints 44513: Hotspots  832: MapLen 24504.933
# Run    21500: LK -45674987.040: ChangePoints 44371: Hotspots  857: MapLen 24743.957
# Run    22000: LK -45672679.381: ChangePoints 44265: Hotspots  854: MapLen 24438.689
# Run    22500: LK -45671652.617: ChangePoints 44124: Hotspots  860: MapLen 24139.394
# Run    23000: LK -45670698.359: ChangePoints 44003: Hotspots  841: MapLen 23763.041
# Run    23500: LK -45669478.631: ChangePoints 43877: Hotspots  845: MapLen 24637.284
# Run    24000: LK -45669848.383: ChangePoints 43782: Hotspots  839: MapLen 24161.079
# Run    24500: LK -45666284.104: ChangePoints 43649: Hotspots  852: MapLen 24154.035
# Run    25000: LK -45662838.986: ChangePoints 43544: Hotspots  855: MapLen 24128.352
# Run    25500: LK -45660212.742: ChangePoints 43405: Hotspots  874: MapLen 25265.012
# Run    26000: LK -45660111.673: ChangePoints 43282: Hotspots  871: MapLen 25750.418
# Run    26500: LK -45658291.830: ChangePoints 43178: Hotspots  888: MapLen 26199.409
# Run    27000: LK -45654624.816: ChangePoints 43080: Hotspots  881: MapLen 26709.194
# Run    27500: LK -45653292.077: ChangePoints 42981: Hotspots  872: MapLen 26343.282
# Run    28000: LK -45654554.830: ChangePoints 42862: Hotspots  873: MapLen 26578.512
# Run    28500: LK -45654373.784: ChangePoints 42764: Hotspots  861: MapLen 26128.178
# Run    29000: LK -45650975.521: ChangePoints 42639: Hotspots  852: MapLen 24513.633
# Run    29500: LK -45647889.476: ChangePoints 42513: Hotspots  867: MapLen 24535.126
# Run    30000: LK -45643544.117: ChangePoints 42388: Hotspots  878: MapLen 24842.547
# Run    30500: LK -45643738.137: ChangePoints 42247: Hotspots  881: MapLen 24974.368
# Run    31000: LK -45640205.762: ChangePoints 42117: Hotspots  888: MapLen 24925.703
# Run    31500: LK -45636500.332: ChangePoints 42004: Hotspots  888: MapLen 25087.807
# Run    32000: LK -45633059.030: ChangePoints 41885: Hotspots  901: MapLen 25147.180
# Run    32500: LK -45633666.117: ChangePoints 41765: Hotspots  904: MapLen 25926.161
# Run    33000: LK -45629979.596: ChangePoints 41660: Hotspots  905: MapLen 26093.255
# Run    33500: LK -45629930.290: ChangePoints 41530: Hotspots  914: MapLen 26642.608
# Run    34000: LK -45627923.794: ChangePoints 41417: Hotspots  908: MapLen 25910.583
# Run    34500: LK -45628393.657: ChangePoints 41301: Hotspots  902: MapLen 25773.716
# Run    35000: LK -45627436.075: ChangePoints 41192: Hotspots  895: MapLen 25583.398
# Run    35500: LK -45627413.835: ChangePoints 41087: Hotspots  909: MapLen 25932.717
# Run    36000: LK -45627185.926: ChangePoints 40974: Hotspots  914: MapLen 25891.432
# Run    36500: LK -45625446.789: ChangePoints 40853: Hotspots  911: MapLen 25385.137
# Run    37000: LK -45623653.571: ChangePoints 40736: Hotspots  915: MapLen 25744.012
# Run    37500: LK -45622864.909: ChangePoints 40604: Hotspots  905: MapLen 25679.426
# Run    38000: LK -45620882.897: ChangePoints 40488: Hotspots  902: MapLen 26093.914
# Run    38500: LK -45621465.226: ChangePoints 40371: Hotspots  904: MapLen 26513.486
# Run    39000: LK -45620009.517: ChangePoints 40238: Hotspots  897: MapLen 26370.792
# Run    39500: LK -45617576.468: ChangePoints 40134: Hotspots  896: MapLen 26131.176
# Run    40000: LK -45614949.867: ChangePoints 40009: Hotspots  911: MapLen 26766.182
# Run    40500: LK -45614304.153: ChangePoints 39910: Hotspots  906: MapLen 26090.542
# Run    41000: LK -45610006.234: ChangePoints 39763: Hotspots  916: MapLen 26137.714
# Run    41500: LK -45611772.340: ChangePoints 39671: Hotspots  904: MapLen 25772.419
# Run    42000: LK -45610215.445: ChangePoints 39581: Hotspots  913: MapLen 25824.563
# Run    42500: LK -45609223.989: ChangePoints 39472: Hotspots  929: MapLen 26163.399
# Run    43000: LK -45610513.104: ChangePoints 39341: Hotspots  919: MapLen 25748.972
# Run    43500: LK -45610602.824: ChangePoints 39221: Hotspots  926: MapLen 26427.310
# Run    44000: LK -45609935.945: ChangePoints 39124: Hotspots  927: MapLen 26743.687
# Run    44500: LK -45606908.713: ChangePoints 38995: Hotspots  932: MapLen 27071.594
# Run    45000: LK -45604912.665: ChangePoints 38873: Hotspots  935: MapLen 27669.337
# Run    45500: LK -45605792.143: ChangePoints 38770: Hotspots  936: MapLen 26970.745
# Run    46000: LK -45604331.083: ChangePoints 38663: Hotspots  947: MapLen 27695.433
# Run    46500: LK -45603538.736: ChangePoints 38562: Hotspots  951: MapLen 28162.581
# Run    47000: LK -45603946.139: ChangePoints 38446: Hotspots  954: MapLen 28023.446
# Run    47500: LK -45603488.253: ChangePoints 38357: Hotspots  955: MapLen 28193.419
# Run    48000: LK -45603192.953: ChangePoints 38247: Hotspots  957: MapLen 28176.406
# Run    48500: LK -45601397.233: ChangePoints 38151: Hotspots  957: MapLen 28208.070
# Run    49000: LK -45600962.358: ChangePoints 38045: Hotspots  960: MapLen 27755.227
# Run    49500: LK -45602625.983: ChangePoints 37946: Hotspots  960: MapLen 27439.644
# Run    50000: LK -45602879.239: ChangePoints 37837: Hotspots  964: MapLen 27336.823
# Run    50500: LK -45602955.566: ChangePoints 37725: Hotspots  950: MapLen 26891.110
# Run    51000: LK -45601954.559: ChangePoints 37623: Hotspots  940: MapLen 26889.354
# Run    51500: LK -45603002.562: ChangePoints 37509: Hotspots  936: MapLen 26868.863
# Run    52000: LK -45600875.670: ChangePoints 37413: Hotspots  940: MapLen 27458.739
# Run    52500: LK -45599802.260: ChangePoints 37283: Hotspots  965: MapLen 27563.296
# Run    53000: LK -45598277.151: ChangePoints 37173: Hotspots  964: MapLen 27867.517
# Run    53500: LK -45598180.518: ChangePoints 37056: Hotspots  956: MapLen 27975.058
# Run    54000: LK -45597839.462: ChangePoints 36964: Hotspots  951: MapLen 27624.391
# Run    54500: LK -45598899.800: ChangePoints 36852: Hotspots  940: MapLen 27161.366
# Run    55000: LK -45599675.540: ChangePoints 36736: Hotspots  942: MapLen 26863.213
# Run    55500: LK -45600201.629: ChangePoints 36611: Hotspots  946: MapLen 26887.741
# Run    56000: LK -45600034.345: ChangePoints 36508: Hotspots  962: MapLen 27747.703
# Run    56500: LK -45600118.797: ChangePoints 36413: Hotspots  978: MapLen 28314.692
# Run    57000: LK -45599283.186: ChangePoints 36323: Hotspots  965: MapLen 27611.959
# Run    57500: LK -45599930.536: ChangePoints 36232: Hotspots  968: MapLen 28019.420
# Run    58000: LK -45599599.426: ChangePoints 36135: Hotspots  955: MapLen 27162.301
# Run    58500: LK -45599885.265: ChangePoints 36022: Hotspots  943: MapLen 26790.949
# Run    59000: LK -45599375.001: ChangePoints 35920: Hotspots  943: MapLen 26958.996
# Run    59500: LK -45598879.657: ChangePoints 35821: Hotspots  935: MapLen 26027.074
# Run    60000: LK -45597353.925: ChangePoints 35737: Hotspots  940: MapLen 26126.971
# Run    60500: LK -45596497.194: ChangePoints 35642: Hotspots  936: MapLen 26181.825
# Run    61000: LK -45596280.085: ChangePoints 35545: Hotspots  934: MapLen 26600.534
# Run    61500: LK -45596584.608: ChangePoints 35433: Hotspots  932: MapLen 26593.813
# Run    62000: LK -45594526.546: ChangePoints 35325: Hotspots  938: MapLen 26960.697
# Run    62500: LK -45594644.644: ChangePoints 35225: Hotspots  919: MapLen 26196.693
# Run    63000: LK -45593527.139: ChangePoints 35127: Hotspots  925: MapLen 26089.133
# Run    63500: LK -45593424.304: ChangePoints 35025: Hotspots  931: MapLen 26781.428
# Run    64000: LK -45594016.662: ChangePoints 34934: Hotspots  931: MapLen 26880.350
# Run    64500: LK -45595637.102: ChangePoints 34849: Hotspots  933: MapLen 26624.433
# Run    65000: LK -45594543.414: ChangePoints 34738: Hotspots  939: MapLen 26369.600
# Run    65500: LK -45594121.272: ChangePoints 34652: Hotspots  934: MapLen 26228.628
# Run    66000: LK -45594532.049: ChangePoints 34537: Hotspots  941: MapLen 26376.777
# Run    66500: LK -45593728.997: ChangePoints 34435: Hotspots  945: MapLen 25931.799
# Run    67000: LK -45594436.346: ChangePoints 34345: Hotspots  941: MapLen 26216.380
# Run    67500: LK -45594500.566: ChangePoints 34243: Hotspots  937: MapLen 26478.538
# Run    68000: LK -45593769.222: ChangePoints 34137: Hotspots  937: MapLen 26667.997
# Run    68500: LK -45593179.832: ChangePoints 34047: Hotspots  937: MapLen 26531.431
# Run    69000: LK -45594338.141: ChangePoints 33956: Hotspots  937: MapLen 26691.293
# Run    69500: LK -45594686.148: ChangePoints 33864: Hotspots  928: MapLen 26312.714
# Run    70000: LK -45593792.623: ChangePoints 33768: Hotspots  922: MapLen 26117.210
# Run    70500: LK -45592213.400: ChangePoints 33677: Hotspots  931: MapLen 25832.230
# Run    71000: LK -45591495.446: ChangePoints 33582: Hotspots  929: MapLen 26046.353
# Run    71500: LK -45589004.154: ChangePoints 33491: Hotspots  946: MapLen 26436.749
# Run    72000: LK -45587294.344: ChangePoints 33366: Hotspots  948: MapLen 26990.819
# Run    72500: LK -45586095.820: ChangePoints 33240: Hotspots  947: MapLen 26325.395
# Run    73000: LK -45587418.559: ChangePoints 33141: Hotspots  946: MapLen 26256.142
# Run    73500: LK -45586060.963: ChangePoints 33056: Hotspots  938: MapLen 26318.525
# Run    74000: LK -45586633.918: ChangePoints 32943: Hotspots  949: MapLen 26617.579
# Run    74500: LK -45587112.821: ChangePoints 32840: Hotspots  945: MapLen 26677.948
# Run    75000: LK -45588451.299: ChangePoints 32750: Hotspots  950: MapLen 26889.335
# Run    75500: LK -45589398.372: ChangePoints 32645: Hotspots  941: MapLen 26947.964
# Run    76000: LK -45586719.101: ChangePoints 32550: Hotspots  944: MapLen 26368.612
# Run    76500: LK -45584147.342: ChangePoints 32444: Hotspots  953: MapLen 26975.778
# Run    77000: LK -45583781.935: ChangePoints 32350: Hotspots  956: MapLen 27086.744
# Run    77500: LK -45583010.310: ChangePoints 32268: Hotspots  966: MapLen 27399.685
# Run    78000: LK -45580756.880: ChangePoints 32157: Hotspots  969: MapLen 27762.132
# Run    78500: LK -45581783.739: ChangePoints 32075: Hotspots  953: MapLen 26786.424
# Run    79000: LK -45581480.450: ChangePoints 31948: Hotspots  949: MapLen 26490.775
# Run    79500: LK -45580687.501: ChangePoints 31851: Hotspots  935: MapLen 26445.378
# Run    80000: LK -45578585.049: ChangePoints 31750: Hotspots  943: MapLen 26895.266
# Run    80500: LK -45579626.777: ChangePoints 31668: Hotspots  947: MapLen 26348.891
# Run    81000: LK -45580893.705: ChangePoints 31578: Hotspots  950: MapLen 26264.159
# Run    81500: LK -45584029.841: ChangePoints 31498: Hotspots  929: MapLen 26464.491
# Run    82000: LK -45581667.612: ChangePoints 31402: Hotspots  947: MapLen 26865.707
# Run    82500: LK -45580884.543: ChangePoints 31301: Hotspots  943: MapLen 27332.768
# Run    83000: LK -45579794.911: ChangePoints 31223: Hotspots  945: MapLen 27193.121
# Run    83500: LK -45579809.516: ChangePoints 31116: Hotspots  951: MapLen 27630.521
# Run    84000: LK -45581373.207: ChangePoints 31044: Hotspots  942: MapLen 27236.805
# Run    84500: LK -45581531.802: ChangePoints 30957: Hotspots  949: MapLen 27158.090
# Run    85000: LK -45580733.796: ChangePoints 30876: Hotspots  947: MapLen 27105.969
# Run    85500: LK -45581187.382: ChangePoints 30761: Hotspots  941: MapLen 26711.085
# Run    86000: LK -45578679.645: ChangePoints 30680: Hotspots  943: MapLen 26949.307
# Run    86500: LK -45579143.721: ChangePoints 30600: Hotspots  935: MapLen 27114.657
# Run    87000: LK -45580043.724: ChangePoints 30507: Hotspots  937: MapLen 27089.031
# Run    87500: LK -45582420.730: ChangePoints 30429: Hotspots  927: MapLen 26997.620
# Run    88000: LK -45580928.028: ChangePoints 30335: Hotspots  947: MapLen 27126.874
# Run    88500: LK -45581609.773: ChangePoints 30270: Hotspots  952: MapLen 26963.950
# Run    89000: LK -45582542.694: ChangePoints 30185: Hotspots  955: MapLen 26984.216
# Run    89500: LK -45583848.134: ChangePoints 30113: Hotspots  951: MapLen 26979.893
# Run    90000: LK -45584217.165: ChangePoints 30029: Hotspots  956: MapLen 27170.099
# Run    90500: LK -45583790.995: ChangePoints 29963: Hotspots  954: MapLen 27481.651
# Run    91000: LK -45582886.127: ChangePoints 29866: Hotspots  951: MapLen 26760.364
# Run    91500: LK -45583474.774: ChangePoints 29761: Hotspots  944: MapLen 26232.664
# Run    92000: LK -45584776.973: ChangePoints 29660: Hotspots  941: MapLen 25662.186
# Run    92500: LK -45586796.026: ChangePoints 29597: Hotspots  936: MapLen 25684.616
# Run    93000: LK -45587857.474: ChangePoints 29508: Hotspots  930: MapLen 25728.030
# Run    93500: LK -45585842.809: ChangePoints 29420: Hotspots  935: MapLen 26469.962
# Run    94000: LK -45583856.892: ChangePoints 29343: Hotspots  932: MapLen 26058.696
# Run    94500: LK -45583252.749: ChangePoints 29247: Hotspots  937: MapLen 27216.038
# Run    95000: LK -45580383.728: ChangePoints 29154: Hotspots  948: MapLen 26620.733
# Run    95500: LK -45581059.268: ChangePoints 29075: Hotspots  948: MapLen 26691.473
# Run    96000: LK -45580440.245: ChangePoints 28991: Hotspots  956: MapLen 26937.982
# Run    96500: LK -45580873.059: ChangePoints 28905: Hotspots  961: MapLen 27333.686
# Run    97000: LK -45582526.608: ChangePoints 28817: Hotspots  953: MapLen 26981.280
# Run    97500: LK -45580849.872: ChangePoints 28740: Hotspots  938: MapLen 26631.270
# Run    98000: LK -45582328.908: ChangePoints 28665: Hotspots  942: MapLen 26630.059
# Run    98500: LK -45582476.154: ChangePoints 28576: Hotspots  940: MapLen 26081.500
# Run    99000: LK -45582260.714: ChangePoints 28483: Hotspots  941: MapLen 26420.700
# Run    99500: LK -45583641.558: ChangePoints 28414: Hotspots  941: MapLen 26708.265
# Run   100000: LK -45582321.983: ChangePoints 28345: Hotspots  946: MapLen 26608.411
# After 100000 runs - likelihood = -45582321.982880
#
# Final block length = 26608.411229
#
#
# Final Acceptance rates:
# Change Block Rate =   	 0.9140	 Move Changepoint =	 0.5965
# Split Block =         	 0.6570	 Merge blocks =    	 0.6571
# Change Hotspot Heat = 	 0.9146	 Move Hotspot =    	 0.8370
# Insert Hotspot =      	 0.8357	 Delete Hotspot =  	 0.1793
# Change Hotspot Scale =	 0.5657
#
#
# Total Program Run Time
# 210.829 seconds

# %% [markdown]
# West Eurasia:

# %%
Data/software/builds/LDhat/rhomap -seq Results/recmap_data_westeurasia.ldhat.sites \
                                        -loc Results/recmap_data_westeurasia.ldhat.locs \
                                        -prefix Results/recmap_data_westeurasia. \
                                        -lk new_lk.txt -its 100000 -samp 500 -burn 0
# Out:
# Starting rate estimation
# Seed = -1680256331
# Analysing 20 haploid sequences of length 49868 seg sites
# Reading sequences in fasta format
# Reading data for pair types
#
# Checking likelihood file is exhaustive:...OK
# Calculating distribution of pair types
# Completed classification of pair types
# Old = 275: New = 0: Missing = 0
# Max number of haplotypes for n=20 is 275
# Reading likelihoods for pair types
#
# Initial likelihood = -206674.193
#
# Run      500: LK -20637565.265: ChangePoints 49729: Hotspots  110: MapLen 2685.630
# Run     1000: LK -20620199.384: ChangePoints 49601: Hotspots  185: MapLen 5206.251
# Run     1500: LK -20609145.499: ChangePoints 49480: Hotspots  205: MapLen 6334.811
# Run     2000: LK -20596942.067: ChangePoints 49346: Hotspots  227: MapLen 6808.731
# Run     2500: LK -20587580.013: ChangePoints 49208: Hotspots  255: MapLen 8046.863
# Run     3000: LK -20580238.081: ChangePoints 49090: Hotspots  267: MapLen 6773.050
# Run     3500: LK -20575033.869: ChangePoints 48927: Hotspots  288: MapLen 6992.619
# Run     4000: LK -20570529.414: ChangePoints 48791: Hotspots  308: MapLen 7641.136
# Run     4500: LK -20568835.354: ChangePoints 48661: Hotspots  303: MapLen 7559.131
# Run     5000: LK -20566175.578: ChangePoints 48525: Hotspots  307: MapLen 7698.203
# Run     5500: LK -20563402.989: ChangePoints 48391: Hotspots  308: MapLen 7834.791
# Run     6000: LK -20559324.924: ChangePoints 48273: Hotspots  338: MapLen 8526.814
# Run     6500: LK -20555026.496: ChangePoints 48147: Hotspots  338: MapLen 8787.538
# Run     7000: LK -20553293.468: ChangePoints 48012: Hotspots  338: MapLen 8940.772
# Run     7500: LK -20553577.535: ChangePoints 47883: Hotspots  325: MapLen 8638.860
# Run     8000: LK -20551075.800: ChangePoints 47766: Hotspots  329: MapLen 8605.799
# Run     8500: LK -20549735.848: ChangePoints 47632: Hotspots  327: MapLen 8082.078
# Run     9000: LK -20545333.172: ChangePoints 47488: Hotspots  332: MapLen 7960.884
# Run     9500: LK -20544170.057: ChangePoints 47362: Hotspots  333: MapLen 7843.300
# Run    10000: LK -20542525.809: ChangePoints 47207: Hotspots  333: MapLen 8154.243
# Run    10500: LK -20543391.438: ChangePoints 47084: Hotspots  336: MapLen 8486.677
# Run    11000: LK -20541256.522: ChangePoints 46947: Hotspots  349: MapLen 8909.031
# Run    11500: LK -20540667.742: ChangePoints 46839: Hotspots  342: MapLen 8459.126
# Run    12000: LK -20538909.979: ChangePoints 46705: Hotspots  340: MapLen 8857.011
# Run    12500: LK -20539802.049: ChangePoints 46586: Hotspots  346: MapLen 8917.092
# Run    13000: LK -20541572.176: ChangePoints 46448: Hotspots  345: MapLen 8325.680
# Run    13500: LK -20537921.432: ChangePoints 46324: Hotspots  360: MapLen 9188.291
# Run    14000: LK -20537284.427: ChangePoints 46174: Hotspots  378: MapLen 10004.957
# Run    14500: LK -20535830.076: ChangePoints 46023: Hotspots  387: MapLen 9382.735
# Run    15000: LK -20533548.043: ChangePoints 45875: Hotspots  379: MapLen 8448.285
# Run    15500: LK -20533593.251: ChangePoints 45729: Hotspots  363: MapLen 8210.739
# Run    16000: LK -20531862.849: ChangePoints 45591: Hotspots  369: MapLen 8261.222
# Run    16500: LK -20531834.714: ChangePoints 45469: Hotspots  369: MapLen 7359.282
# Run    17000: LK -20530864.710: ChangePoints 45328: Hotspots  358: MapLen 7721.826
# Run    17500: LK -20531247.594: ChangePoints 45235: Hotspots  364: MapLen 7884.669
# Run    18000: LK -20532477.831: ChangePoints 45110: Hotspots  376: MapLen 8061.946
# Run    18500: LK -20533561.280: ChangePoints 44992: Hotspots  354: MapLen 7725.883
# Run    19000: LK -20534616.916: ChangePoints 44847: Hotspots  346: MapLen 7862.462
# Run    19500: LK -20535146.305: ChangePoints 44731: Hotspots  349: MapLen 8117.932
# Run    20000: LK -20534055.728: ChangePoints 44623: Hotspots  338: MapLen 7635.292
# Run    20500: LK -20534952.571: ChangePoints 44498: Hotspots  350: MapLen 8370.019
# Run    21000: LK -20533715.952: ChangePoints 44390: Hotspots  342: MapLen 7958.185
# Run    21500: LK -20533111.337: ChangePoints 44281: Hotspots  347: MapLen 7853.132
# Run    22000: LK -20532077.945: ChangePoints 44169: Hotspots  356: MapLen 7912.341
# Run    22500: LK -20532651.137: ChangePoints 44042: Hotspots  352: MapLen 7534.540
# Run    23000: LK -20533299.530: ChangePoints 43939: Hotspots  344: MapLen 7694.752
# Run    23500: LK -20530922.822: ChangePoints 43825: Hotspots  348: MapLen 7511.444
# Run    24000: LK -20531041.874: ChangePoints 43706: Hotspots  367: MapLen 8044.937
# Run    24500: LK -20529341.905: ChangePoints 43593: Hotspots  373: MapLen 9004.265
# Run    25000: LK -20529522.377: ChangePoints 43496: Hotspots  366: MapLen 9232.149
# Run    25500: LK -20529943.494: ChangePoints 43354: Hotspots  355: MapLen 8707.476
# Run    26000: LK -20527641.052: ChangePoints 43247: Hotspots  375: MapLen 9586.672
# Run    26500: LK -20527133.163: ChangePoints 43144: Hotspots  362: MapLen 9299.826
# Run    27000: LK -20526270.985: ChangePoints 42999: Hotspots  366: MapLen 8848.277
# Run    27500: LK -20526990.749: ChangePoints 42888: Hotspots  371: MapLen 9295.960
# Run    28000: LK -20527148.044: ChangePoints 42771: Hotspots  367: MapLen 9626.221
# Run    28500: LK -20524899.679: ChangePoints 42666: Hotspots  384: MapLen 8638.265
# Run    29000: LK -20524275.119: ChangePoints 42551: Hotspots  384: MapLen 8438.632
# Run    29500: LK -20522211.102: ChangePoints 42427: Hotspots  378: MapLen 8765.895
# Run    30000: LK -20523156.980: ChangePoints 42269: Hotspots  375: MapLen 8323.540
# Run    30500: LK -20523137.735: ChangePoints 42115: Hotspots  366: MapLen 8341.675
# Run    31000: LK -20524535.796: ChangePoints 41995: Hotspots  375: MapLen 8822.287
# Run    31500: LK -20525398.647: ChangePoints 41856: Hotspots  371: MapLen 8989.702
# Run    32000: LK -20524741.095: ChangePoints 41751: Hotspots  370: MapLen 8499.567
# Run    32500: LK -20524990.234: ChangePoints 41629: Hotspots  370: MapLen 9190.232
# Run    33000: LK -20525406.405: ChangePoints 41506: Hotspots  369: MapLen 9164.427
# Run    33500: LK -20525277.242: ChangePoints 41408: Hotspots  361: MapLen 9204.622
# Run    34000: LK -20523607.778: ChangePoints 41279: Hotspots  367: MapLen 9379.127
# Run    34500: LK -20524587.069: ChangePoints 41160: Hotspots  365: MapLen 9086.537
# Run    35000: LK -20523610.347: ChangePoints 41020: Hotspots  362: MapLen 8607.475
# Run    35500: LK -20523360.900: ChangePoints 40913: Hotspots  360: MapLen 8552.778
# Run    36000: LK -20522182.409: ChangePoints 40808: Hotspots  383: MapLen 9281.150
# Run    36500: LK -20522295.550: ChangePoints 40682: Hotspots  382: MapLen 9118.608
# Run    37000: LK -20521027.884: ChangePoints 40575: Hotspots  376: MapLen 8451.140
# Run    37500: LK -20521033.325: ChangePoints 40473: Hotspots  372: MapLen 9113.602
# Run    38000: LK -20524537.487: ChangePoints 40372: Hotspots  384: MapLen 9568.199
# Run    38500: LK -20525136.481: ChangePoints 40244: Hotspots  376: MapLen 10161.536
# Run    39000: LK -20525813.442: ChangePoints 40127: Hotspots  374: MapLen 10152.178
# Run    39500: LK -20524071.212: ChangePoints 40013: Hotspots  367: MapLen 9898.936
# Run    40000: LK -20524651.054: ChangePoints 39911: Hotspots  353: MapLen 8826.092
# Run    40500: LK -20525780.007: ChangePoints 39802: Hotspots  352: MapLen 8385.217
# Run    41000: LK -20524835.676: ChangePoints 39707: Hotspots  360: MapLen 8505.700
# Run    41500: LK -20525962.533: ChangePoints 39608: Hotspots  354: MapLen 9101.375
# Run    42000: LK -20523459.884: ChangePoints 39498: Hotspots  342: MapLen 8570.256
# Run    42500: LK -20522694.523: ChangePoints 39383: Hotspots  351: MapLen 8061.153
# Run    43000: LK -20524596.966: ChangePoints 39277: Hotspots  357: MapLen 9586.053
# Run    43500: LK -20524132.319: ChangePoints 39143: Hotspots  364: MapLen 9605.701
# Run    44000: LK -20523482.271: ChangePoints 39054: Hotspots  378: MapLen 9712.753
# Run    44500: LK -20523136.473: ChangePoints 38958: Hotspots  373: MapLen 10264.071
# Run    45000: LK -20524219.393: ChangePoints 38862: Hotspots  373: MapLen 10278.345
# Run    45500: LK -20524516.222: ChangePoints 38750: Hotspots  358: MapLen 9046.642
# Run    46000: LK -20525749.118: ChangePoints 38666: Hotspots  364: MapLen 9006.431
# Run    46500: LK -20524088.474: ChangePoints 38547: Hotspots  373: MapLen 9317.542
# Run    47000: LK -20526536.903: ChangePoints 38436: Hotspots  359: MapLen 9335.117
# Run    47500: LK -20528063.801: ChangePoints 38321: Hotspots  350: MapLen 9364.873
# Run    48000: LK -20526750.401: ChangePoints 38199: Hotspots  346: MapLen 8654.845
# Run    48500: LK -20526756.387: ChangePoints 38086: Hotspots  348: MapLen 8736.283
# Run    49000: LK -20525552.712: ChangePoints 37960: Hotspots  350: MapLen 8947.882
# Run    49500: LK -20523961.947: ChangePoints 37816: Hotspots  356: MapLen 9147.250
# Run    50000: LK -20523859.073: ChangePoints 37700: Hotspots  352: MapLen 8775.420
# Run    50500: LK -20521895.766: ChangePoints 37572: Hotspots  376: MapLen 9892.321
# Run    51000: LK -20524344.815: ChangePoints 37458: Hotspots  383: MapLen 10067.288
# Run    51500: LK -20526607.395: ChangePoints 37345: Hotspots  390: MapLen 10284.649
# Run    52000: LK -20525384.125: ChangePoints 37219: Hotspots  378: MapLen 9626.797
# Run    52500: LK -20523888.634: ChangePoints 37113: Hotspots  371: MapLen 9319.951
# Run    53000: LK -20524115.266: ChangePoints 37001: Hotspots  357: MapLen 9006.062
# Run    53500: LK -20524953.929: ChangePoints 36901: Hotspots  360: MapLen 9360.496
# Run    54000: LK -20527536.345: ChangePoints 36780: Hotspots  356: MapLen 10219.250
# Run    54500: LK -20527606.622: ChangePoints 36660: Hotspots  363: MapLen 9946.201
# Run    55000: LK -20527700.781: ChangePoints 36560: Hotspots  374: MapLen 10690.851
# Run    55500: LK -20523048.724: ChangePoints 36448: Hotspots  354: MapLen 9297.514
# Run    56000: LK -20521405.303: ChangePoints 36353: Hotspots  358: MapLen 9274.925
# Run    56500: LK -20521245.119: ChangePoints 36228: Hotspots  356: MapLen 9261.272
# Run    57000: LK -20520824.142: ChangePoints 36145: Hotspots  365: MapLen 9382.386
# Run    57500: LK -20521308.941: ChangePoints 36037: Hotspots  353: MapLen 9614.072
# Run    58000: LK -20520904.195: ChangePoints 35933: Hotspots  357: MapLen 9141.033
# Run    58500: LK -20520453.969: ChangePoints 35860: Hotspots  373: MapLen 9042.544
# Run    59000: LK -20519069.742: ChangePoints 35769: Hotspots  363: MapLen 8854.408
# Run    59500: LK -20519591.236: ChangePoints 35692: Hotspots  355: MapLen 8358.631
# Run    60000: LK -20518192.674: ChangePoints 35584: Hotspots  376: MapLen 9043.105
# Run    60500: LK -20519091.054: ChangePoints 35466: Hotspots  362: MapLen 8931.473
# Run    61000: LK -20519286.241: ChangePoints 35359: Hotspots  366: MapLen 8750.625
# Run    61500: LK -20521152.478: ChangePoints 35261: Hotspots  372: MapLen 9005.703
# Run    62000: LK -20521195.336: ChangePoints 35158: Hotspots  372: MapLen 9216.956
# Run    62500: LK -20520500.406: ChangePoints 35051: Hotspots  378: MapLen 9079.495
# Run    63000: LK -20521695.756: ChangePoints 34944: Hotspots  371: MapLen 9108.504
# Run    63500: LK -20522298.647: ChangePoints 34859: Hotspots  373: MapLen 8885.528
# Run    64000: LK -20522380.579: ChangePoints 34744: Hotspots  364: MapLen 8559.849
# Run    64500: LK -20523167.134: ChangePoints 34624: Hotspots  374: MapLen 9050.872
# Run    65000: LK -20521914.264: ChangePoints 34530: Hotspots  364: MapLen 8188.023
# Run    65500: LK -20522558.593: ChangePoints 34427: Hotspots  371: MapLen 8517.367
# Run    66000: LK -20521084.742: ChangePoints 34344: Hotspots  361: MapLen 8230.269
# Run    66500: LK -20521134.948: ChangePoints 34218: Hotspots  354: MapLen 8504.366
# Run    67000: LK -20518492.087: ChangePoints 34119: Hotspots  362: MapLen 8734.932
# Run    67500: LK -20517778.900: ChangePoints 34015: Hotspots  356: MapLen 8565.208
# Run    68000: LK -20519468.871: ChangePoints 33912: Hotspots  366: MapLen 8887.542
# Run    68500: LK -20517721.195: ChangePoints 33838: Hotspots  376: MapLen 9118.751
# Run    69000: LK -20520176.335: ChangePoints 33746: Hotspots  366: MapLen 8600.773
# Run    69500: LK -20519072.563: ChangePoints 33637: Hotspots  379: MapLen 8328.423
# Run    70000: LK -20519466.253: ChangePoints 33540: Hotspots  360: MapLen 8654.051
# Run    70500: LK -20521530.860: ChangePoints 33448: Hotspots  362: MapLen 9418.097
# Run    71000: LK -20521376.227: ChangePoints 33356: Hotspots  376: MapLen 9143.955
# Run    71500: LK -20518430.603: ChangePoints 33237: Hotspots  401: MapLen 9519.871
# Run    72000: LK -20519214.606: ChangePoints 33157: Hotspots  383: MapLen 9864.865
# Run    72500: LK -20520745.075: ChangePoints 33070: Hotspots  378: MapLen 9842.729
# Run    73000: LK -20522893.628: ChangePoints 32970: Hotspots  380: MapLen 9816.706
# Run    73500: LK -20521496.217: ChangePoints 32888: Hotspots  390: MapLen 10306.881
# Run    74000: LK -20520762.984: ChangePoints 32771: Hotspots  379: MapLen 9623.369
# Run    74500: LK -20519846.594: ChangePoints 32665: Hotspots  370: MapLen 9532.314
# Run    75000: LK -20521783.661: ChangePoints 32571: Hotspots  367: MapLen 9365.461
# Run    75500: LK -20520253.578: ChangePoints 32486: Hotspots  384: MapLen 8979.258
# Run    76000: LK -20518860.558: ChangePoints 32399: Hotspots  390: MapLen 9015.624
# Run    76500: LK -20519887.843: ChangePoints 32289: Hotspots  375: MapLen 9058.036
# Run    77000: LK -20521450.113: ChangePoints 32193: Hotspots  369: MapLen 9340.468
# Run    77500: LK -20521580.544: ChangePoints 32098: Hotspots  372: MapLen 8851.805
# Run    78000: LK -20518161.684: ChangePoints 32018: Hotspots  382: MapLen 9078.829
# Run    78500: LK -20520120.506: ChangePoints 31915: Hotspots  372: MapLen 8571.083
# Run    79000: LK -20518465.848: ChangePoints 31834: Hotspots  381: MapLen 8986.846
# Run    79500: LK -20516911.660: ChangePoints 31745: Hotspots  386: MapLen 9091.942
# Run    80000: LK -20518318.043: ChangePoints 31642: Hotspots  394: MapLen 8915.255
# Run    80500: LK -20518312.445: ChangePoints 31566: Hotspots  398: MapLen 8908.682
# Run    81000: LK -20518466.322: ChangePoints 31496: Hotspots  407: MapLen 8830.525
# Run    81500: LK -20519789.090: ChangePoints 31396: Hotspots  405: MapLen 9953.856
# Run    82000: LK -20518092.907: ChangePoints 31314: Hotspots  408: MapLen 10521.038
# Run    82500: LK -20519094.770: ChangePoints 31236: Hotspots  397: MapLen 10949.994
# Run    83000: LK -20520346.605: ChangePoints 31141: Hotspots  375: MapLen 10947.916
# Run    83500: LK -20520303.008: ChangePoints 31053: Hotspots  364: MapLen 10237.601
# Run    84000: LK -20520200.856: ChangePoints 30948: Hotspots  385: MapLen 10106.683
# Run    84500: LK -20520681.991: ChangePoints 30849: Hotspots  365: MapLen 9611.584
# Run    85000: LK -20518964.715: ChangePoints 30743: Hotspots  369: MapLen 9454.136
# Run    85500: LK -20519962.903: ChangePoints 30648: Hotspots  366: MapLen 9651.666
# Run    86000: LK -20519977.293: ChangePoints 30557: Hotspots  384: MapLen 9532.743
# Run    86500: LK -20521482.186: ChangePoints 30473: Hotspots  389: MapLen 9489.894
# Run    87000: LK -20521069.163: ChangePoints 30383: Hotspots  374: MapLen 9106.866
# Run    87500: LK -20520762.608: ChangePoints 30301: Hotspots  369: MapLen 9471.219
# Run    88000: LK -20517946.800: ChangePoints 30184: Hotspots  376: MapLen 9076.611
# Run    88500: LK -20518469.123: ChangePoints 30094: Hotspots  363: MapLen 9015.554
# Run    89000: LK -20519697.883: ChangePoints 30001: Hotspots  368: MapLen 8877.870
# Run    89500: LK -20518784.845: ChangePoints 29904: Hotspots  366: MapLen 8277.948
# Run    90000: LK -20517996.241: ChangePoints 29806: Hotspots  364: MapLen 8093.032
# Run    90500: LK -20519409.289: ChangePoints 29726: Hotspots  368: MapLen 8240.963
# Run    91000: LK -20519783.944: ChangePoints 29651: Hotspots  371: MapLen 8260.035
# Run    91500: LK -20519490.292: ChangePoints 29558: Hotspots  358: MapLen 8040.861
# Run    92000: LK -20519658.691: ChangePoints 29470: Hotspots  347: MapLen 7716.249
# Run    92500: LK -20520166.346: ChangePoints 29383: Hotspots  359: MapLen 6858.055
# Run    93000: LK -20521816.328: ChangePoints 29294: Hotspots  352: MapLen 7051.643
# Run    93500: LK -20521799.936: ChangePoints 29210: Hotspots  360: MapLen 7187.893
# Run    94000: LK -20521633.453: ChangePoints 29117: Hotspots  350: MapLen 7150.066
# Run    94500: LK -20522425.732: ChangePoints 29012: Hotspots  369: MapLen 7765.256
# Run    95000: LK -20521584.192: ChangePoints 28932: Hotspots  371: MapLen 8169.350
# Run    95500: LK -20523464.211: ChangePoints 28852: Hotspots  377: MapLen 8441.930
# Run    96000: LK -20523741.914: ChangePoints 28784: Hotspots  351: MapLen 7827.630
# Run    96500: LK -20524567.173: ChangePoints 28701: Hotspots  339: MapLen 8037.972
# Run    97000: LK -20523830.646: ChangePoints 28619: Hotspots  328: MapLen 7254.209
# Run    97500: LK -20522610.683: ChangePoints 28538: Hotspots  360: MapLen 7864.330
# Run    98000: LK -20522525.729: ChangePoints 28441: Hotspots  369: MapLen 8120.599
# Run    98500: LK -20521727.113: ChangePoints 28366: Hotspots  388: MapLen 8382.295
# Run    99000: LK -20521136.707: ChangePoints 28278: Hotspots  361: MapLen 7911.505
# Run    99500: LK -20522469.612: ChangePoints 28179: Hotspots  350: MapLen 8382.178
# Run   100000: LK -20521467.996: ChangePoints 28093: Hotspots  348: MapLen 8060.448
# After 100000 runs - likelihood = -20521467.996341
#
# Final block length = 8060.448196
#
#
# Final Acceptance rates:
# Change Block Rate =   	 0.9112	 Move Changepoint =	 0.5972
# Split Block =         	 0.6571	 Merge blocks =    	 0.6605
# Change Hotspot Heat = 	 0.9181	 Move Hotspot =    	 0.8547
# Insert Hotspot =      	 0.5884	 Delete Hotspot =  	 0.3277
# Change Hotspot Scale =	 0.5647
#
#
# Total Program Run Time
# 208.018 seconds

# %% [markdown]
# When `rhomap` completes, it writes three files:
#
# - `acceptance_rates.txt`: acceptance rates of the MCMC. If they are lower than 1%. The program should be run with more iterations.
# - `summary.txt`: (quoting the manual) for each SNP interval, the estimated genetic map position, the estimated recombination rate, and the hotspot density (the number of hotspots per kb per iteration).
# - `rates.txt`: (quoting the manual) is the output from each sample detailing the recombination rate (expressed in $4N_e r$ per kb) between each SNP.

# %% [markdown]
# ## Analyze results in R
#
# <img src="img/R.png" alt="R" width="80"> Shift to the `popgen course` kernel
#
# We now import the resulting files from `LDhat` in `R` using a function create by the author of `LDhat`. The resulting summary file from this function will be useful to perform some analysis later on. And we load some practical `R` functions written by the author of LDhat:

# %%
source("Data/software/ldhat.r")

# %% [markdown]
# One of the loaded functions is `summarise.rhomap`, which produces two plots:
# - A graph of the recombination rate across on each polymorphic loci, along with confidence intervals.
# - A plot showing how estimation of recombination rate has progressed with each MCMC sample. Notice that the initial run of MCMC samples are atypical. This is the "burn-in" of the MCMC. We want to remove that, so take notice of how many samples it corresponds to. We can produce a new set of estimates that excludes this burn-in using the `stat` program that comes with LDhat:

# %%
summarise.rhomap(rates.file = "Results/recmap_data_africa.rates.txt", 
                 locs.file="Results/recmap_data_africa.ldhat.locs")
# Out:
# Summarise output from MCMC estimation of recombination rates in INTERVAL (LDhat 2.1)
#
# Number of SNPs = 49868
# Number of samples = 200
# Burn-in period = 60 samples
#
# Mean posterior total map length (4Ner) = 26670
#        Mean         q2.5         Median       q97.5
# V1     2.667266e+04 2.511749e+04 26677.947930 28169.493251
# V2     1.051459e-01 9.195100e-02     0.104735     0.116797
# V3     9.469276e-02 6.010900e-02     0.104735     0.104735
# V4     2.502336e-02 2.497100e-02     0.024971     0.025078
# V5     4.707917e-02 7.953000e-03     0.054155     0.067922
# V6     4.707917e-02 7.953000e-03     0.054155     0.067922
# V7     4.232599e-02 3.083800e-02     0.037831     0.050802
# V8     1.886429e-02 6.547000e-03     0.008479     0.123605
# V9     2.451423e-01 5.654850e-02     0.096562     2.153450
# V10    6.574513e-01 8.719000e-03     0.063185     9.629015
# V11    6.767993e-01 3.545000e-03     0.063185     9.529238
# V12    2.007009e+00 2.165100e-02     0.038081    14.323346
# V13    5.405417e-01 2.197600e-02     0.085232     4.151652
# V14    8.612226e+00 8.523200e-02     0.085650   120.986779
# V15    8.730220e+00 8.523200e-02     0.099059   120.665048
# V16    2.493403e+01 1.217190e-01     0.124236    84.762842
# V17    4.427323e+00 1.176030e-01     0.121719    49.567940
# V18    2.509438e+00 5.696500e-02     0.121719    39.874028
# V19    1.514874e+00 3.616700e-02     0.038404    12.214591
# V20    1.028369e-04 8.300000e-05     0.000097     0.000116
# V21    3.200498e+00 1.133550e-01     0.149979    50.991446
# V22    1.900173e+00 7.966000e-03     0.015078     7.297973
# V23    1.690732e+00 7.966000e-03     0.012330    10.759659
# V24    1.438457e+00 7.966000e-03     0.012330    21.587459
# V25    1.626917e+00 9.073000e-03     0.012330    18.519524
# V26    1.491813e+00 9.073000e-03     0.012388    20.650541
# V27    1.305592e+00 4.054400e-02     0.041233    15.352669
# V28    1.284430e+00 5.220000e-03     0.048816    13.052592
# V29    4.129243e+00 4.619600e-02     0.054636    65.804939
# V30    1.921116e-01 4.786200e-02     0.089015     0.089015
# ⋮      ⋮            ⋮            ⋮            ⋮
# V49839 0.376370865  0.118142     0.118142      0.5355990
# V49840 0.375353057  0.118142     0.118142      3.7976130
# V49841 1.017119475  0.118142     0.118142     12.3595010
# V49842 1.837775730  0.118142     0.118142     23.9512030
# V49843 1.573868582  0.118142     0.118142     16.5748880
# V49844 0.915745482  0.071499     0.118142     14.8601695
# V49845 2.189565518  0.013987     0.013987     31.8091660
# V49846 0.383603170  0.037746     0.043453      6.2447010
# V49847 0.117099574  0.057950     0.066973      0.0709345
# V49848 3.062358496  0.059794     0.064284      0.9838720
# V49849 0.805044348  0.062066     0.064284      3.2207045
# V49850 1.732270277  0.062066     0.064284      0.7954725
# V49851 0.290282596  0.009531     0.016850      5.7271220
# V49852 0.373580709  0.024855     0.024855      4.4814500
# V49853 0.083153780  0.029597     0.049110      0.6191665
# V49854 0.053281844  0.043940     0.045092      0.1390420
# V49855 0.035312092  0.029295     0.036134      0.0371210
# V49856 0.007752411  0.007137     0.007285      0.0089070
# V49857 0.025980879  0.008090     0.022865      0.0653350
# V49858 0.045540511  0.033745     0.047450      0.0480790
# V49859 0.048757674  0.039530     0.048404      0.0640040
# V49860 0.050575638  0.046912     0.050322      0.0545830
# V49861 0.198334752  0.169003     0.187632      0.2551000
# V49862 0.025025830  0.016627     0.019487      0.0635920
# V49863 0.035662809  0.028373     0.034234      0.0645940
# V49864 0.076612965  0.041372     0.076757      0.1134300
# V49865 0.029381270  0.027560     0.028593      0.0373690
# V49866 0.009914716  0.003683     0.012718      0.0208040
# V49867 0.018151745  0.016802     0.018750      0.0188580
# V49868 0.012701489  0.006970     0.008745      0.0187500
# Plot with title “Posterior mean rates”

# %%
summarise.rhomap(rates.file = "Results/recmap_data_westeurasia.rates.txt", 
                 locs.file="Results/recmap_data_westeurasia.ldhat.locs")
# Out:
# Summarise output from MCMC estimation of recombination rates in INTERVAL (LDhat 2.1)
#
# Number of SNPs = 49868
# Number of samples = 200
# Burn-in period = 60 samples
#
# Mean posterior total map length (4Ner) = 9013
#        Mean         q2.5        Median      q97.5
# V1     9.013483e+03 7221.050977 9046.642495 10413.959503
# V2     3.550170e-03    0.002591    0.002591     0.005881
# V3     6.440864e-01    0.034842    0.081629     0.085722
# V4     7.668259e-01    0.075985    0.114089     6.013762
# V5     3.603009e-01    0.001132    0.021861     5.178647
# V6     3.388092e-01    0.005524    0.021861     3.684255
# V7     3.468170e-01    0.017622    0.023146     2.513161
# V8     1.300570e+01    0.045919    0.052677    36.825249
# V9     1.418884e+01    0.045919    0.050014   189.729506
# V10    2.117701e+01    0.039150    0.043282   282.929507
# V11    1.963224e+01    0.033323    0.043282   264.469231
# V12    8.839779e+00    0.027140    0.043282   119.484711
# V13    7.608795e+00    0.026698    0.043282   126.134460
# V14    1.156840e+01    0.026698    0.039945   182.851886
# V15    7.769481e+00    0.029933    0.033170    80.346952
# V16    4.672918e+00    0.029933    0.033170    65.232827
# V17    3.334709e+00    0.029933    0.035777    55.276133
# V18    1.744168e-01    0.020725    0.030618     0.055796
# V19    8.662710e-01    0.015845    0.023115     9.875768
# V20    1.445393e+00    0.015250    0.020710    22.314194
# V21    1.266824e+00    0.036618    0.039385    16.323837
# V22    9.058216e-01    0.036618    0.039385    11.934364
# V23    1.849222e+00    0.023326    0.041591    29.116923
# V24    2.864507e-01    0.058987    0.082615     0.152183
# V25    9.049225e-01    0.058987    0.095752     0.174095
# V26    2.644087e-02    0.024536    0.026571     0.032830
# V27    3.032341e-02    0.026529    0.026666     0.037409
# V28    2.903795e-02    0.026257    0.026257     0.040850
# V29    9.418771e-02    0.030362    0.033401     0.038771
# V30    1.100002e+00    0.000184    0.000184     0.008039
# ⋮      ⋮            ⋮           ⋮           ⋮
# V49839 0.07203582   0.055423    0.068335      0.0906480
# V49840 0.08419976   0.071638    0.081478      0.1006060
# V49841 0.06538175   0.043679    0.059316      0.0921840
# V49842 0.05881947   0.044887    0.056348      0.0930540
# V49843 0.04995348   0.011212    0.044989      0.0942920
# V49844 0.06740447   0.015722    0.063167      0.1324350
# V49845 0.05800374   0.009710    0.015722      0.1324350
# V49846 0.10102645   0.072344    0.103284      0.1334820
# V49847 0.03224083   0.020676    0.033704      0.0364890
# V49848 0.02563311   0.020676    0.025593      0.0289290
# V49849 2.59607591   0.003830    0.003830      0.0076030
# V49850 0.05004030   0.036904    0.054667      0.0841390
# V49851 0.02318197   0.021455    0.021515      0.0405310
# V49852 0.08333178   0.077234    0.085503      0.0855030
# V49853 0.07295623   0.039339    0.077256      0.0917880
# V49854 1.91321497   0.077806    0.077806      0.0914690
# V49855 1.84859707   0.079273    0.085274     24.5023175
# V49856 0.73290906   0.102694    0.112234      1.9367530
# V49857 5.19685035   0.041750    0.044030      0.0448790
# V49858 6.94678587   0.092450    0.099650    142.2737735
# V49859 1.41495593   0.069655    0.128690      8.5391870
# V49860 1.45001420   0.004846    0.006504      0.0077960
# V49861 0.46444435   0.010748    0.010956      3.7157605
# V49862 0.48388333   0.195786    0.195786      0.1957860
# V49863 6.52914630   0.032764    0.032764      0.0400470
# V49864 0.03510216   0.026179    0.035083      0.0414650
# V49865 0.12536455   0.025941    0.027292      0.3461935
# V49866 0.78595562   0.021981    0.026849      5.7742000
# V49867 1.97790601   0.103528    0.107906     31.1261630
# V49868 0.03852867   0.031789    0.042189      0.0464360
# Plot with title “Posterior mean rates”

# %% [markdown]
# <img src="img/bash.png" alt="Bash" width="80"> Shift to the `Bash` kernel

# %% [markdown]
# We run `LDhat stat`. This produces a file called `res.txt` that describes the confidence in the estimated recombination rate along the sequence.

# %%
Data/software/builds/LDhat/stat -input Results/recmap_data_africa.rates.txt \
                                -loc Results/recmap_data_africa.ldhat.locs \
                                -burn 60
mv res.txt Results/recmap_data_africa.res.txt
# Out:
# Reading data: 200 lines (miss first 60) of 49868 points.........Data read successfully
#
#
#
# Mid = 70, L95=4, U95=136
#
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...
#
# Average total change in rate = 210204.812
# Average total # changes = 38727.150

# %%
Data/software/builds/LDhat/stat -input Results/recmap_data_westeurasia.rates.txt \
                                -loc Results/recmap_data_westeurasia.ldhat.locs \
                                -burn 60
mv res.txt Results/recmap_data_westeurasia.res.txt
# Out:
# Reading data: 200 lines (miss first 60) of 49868 points.........Data read successfully
#
#
#
# Mid = 70, L95=4, U95=136
#
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...
#
# Average total change in rate = 67742.162
# Average total # changes = 38292.207

# %% [markdown]
# <img src="img/R.png" alt="R" width="80"> Shift to the `popgen course` kernel
#
# Now we to plot the final results. To have the positions of the loci for which we have estimated mean recombination rates, we will merge the new dataset created with the summary files generated by LDhat:

# %%
library(ggplot2)
library(dplyr)
library(tidyr)
library(magrittr)
# Out:
# Warning message:
# “package ‘ggplot2’ was built under R version 4.1.3”
# Warning message:
# “package ‘dplyr’ was built under R version 4.1.3”
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# “package ‘tidyr’ was built under R version 4.1.3”
# Warning message:
# “package ‘magrittr’ was built under R version 4.1.3”
#
# Attaching package: ‘magrittr’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     extract

# %% [markdown]
# We plot the mean of the recombination rate along genome positions. In blue we visualize the average rec. rate, and in gray the 95% confidence interval

# %%
summary <- read.table('Results/recmap_data_africa.summary.txt', header = T)
rates <- read.table("Results/recmap_data_africa.res.txt", header=T)
rates %>%
  filter(Loci > 0) %>%
  mutate(pos=summary$Position.kb.*1000) %>%
  ggplot(aes(x=pos, y=Mean_rho, ymin=L95, ymax=U95)) +  
  geom_line(color='blue') +
  geom_ribbon(alpha=0.1) +
  theme_bw()
# Out:
# plot without title

# %%
summary <- read.table('Results/recmap_data_westeurasia.summary.txt', header = T)
rates <- read.table("Results/recmap_data_westeurasia.res.txt", header=T)
rates %>%
  filter(Loci > 0) %>%
  mutate(pos=summary$Position.kb.*1000) %>%
  ggplot(aes(x=pos, y=Mean_rho, ymin=L95, ymax=U95)) +  
  geom_line(color='blue') +
  geom_ribbon(alpha=0.1) +
  theme_bw()
# Out:
# plot without title

# %% [markdown]
# Look at the plots and ponder the following questions:
#
# - Are there any recombination hotspots?
# - Are there any regions where the estimated recombination rate is really low?
# - Can you see any hotspots in Africans that are not found in West Eurasians - other the othe way around?
# - What does the recombination rate look like around the lactase gene?
